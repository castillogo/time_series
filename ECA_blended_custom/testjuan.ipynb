# %%
import pandas as pd


#import matplotlib as mpl
#mpl.rcParams['figure.figsize'] = (12,6)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('TG_STAID002759_B.csv', header=None)

# %%
data
# Out:
#             0         1      2      3
# 0       SOUID      DATE     TG   Q_TG
# 1      127488  18760101     22      0
# 2      127488  18760102     25      0
# 3      127488  18760103      3      0
# 4      127488  18760104    -58      0
# ...       ...       ...    ...    ...
# 52682  111448  20200327     92      0
# 52683  111448  20200328     79      0
# 52684  111448  20200329     29      0
# 52685  111448  20200330      6      0
# 52686  111448  20200331     17      0
#
# [52687 rows x 4 columns]

# %%
data = data.drop(data.index[0])
data
# Out:
#             0         1      2      3
# 1      127488  18760101     22      0
# 2      127488  18760102     25      0
# 3      127488  18760103      3      0
# 4      127488  18760104    -58      0
# 5      127488  18760105    -98      0
# ...       ...       ...    ...    ...
# 52682  111448  20200327     92      0
# 52683  111448  20200328     79      0
# 52684  111448  20200329     29      0
# 52685  111448  20200330      6      0
# 52686  111448  20200331     17      0
#
# [52686 rows x 4 columns]

# %%
data=data.reset_index()

# %%
data
# Out:
#        index       0         1      2      3
# 0          1  127488  18760101     22      0
# 1          2  127488  18760102     25      0
# 2          3  127488  18760103      3      0
# 3          4  127488  18760104    -58      0
# 4          5  127488  18760105    -98      0
# ...      ...     ...       ...    ...    ...
# 52681  52682  111448  20200327     92      0
# 52682  52683  111448  20200328     79      0
# 52683  52684  111448  20200329     29      0
# 52684  52685  111448  20200330      6      0
# 52685  52686  111448  20200331     17      0
#
# [52686 rows x 5 columns]

# %%
data = data.rename(columns = {'index':'ID',0:'SQUID', 1:'DATE',2:'TG',
                     3:'Q_TG'})

# %%
data
# Out:
#           ID   SQUID      DATE     TG   Q_TG
# 0          1  127488  18760101     22      0
# 1          2  127488  18760102     25      0
# 2          3  127488  18760103      3      0
# 3          4  127488  18760104    -58      0
# 4          5  127488  18760105    -98      0
# ...      ...     ...       ...    ...    ...
# 52681  52682  111448  20200327     92      0
# 52682  52683  111448  20200328     79      0
# 52683  52684  111448  20200329     29      0
# 52684  52685  111448  20200330      6      0
# 52685  52686  111448  20200331     17      0
#
# [52686 rows x 5 columns]

# %%
data = data.astype('int32')

# %%
data
# Out:
#           ID   SQUID      DATE  TG  Q_TG
# 0          1  127488  18760101  22     0
# 1          2  127488  18760102  25     0
# 2          3  127488  18760103   3     0
# 3          4  127488  18760104 -58     0
# 4          5  127488  18760105 -98     0
# ...      ...     ...       ...  ..   ...
# 52681  52682  111448  20200327  92     0
# 52682  52683  111448  20200328  79     0
# 52683  52684  111448  20200329  29     0
# 52684  52685  111448  20200330   6     0
# 52685  52686  111448  20200331  17     0
#
# [52686 rows x 5 columns]

# %%
data = data[data.TG > -8000]

# %%
plt.close('all')
fsize = 20

fig_A = plt.figure('DATE vs TG')
ax_A = fig_A.add_subplot(111)

ax_A.scatter(data['DATE'], data['TG'], s=0.001)
plt.show()

# %%
#data['DATE']=pd.to_datetime(data.DATE)

# %%
data
# Out:
#           ID   SQUID      DATE  TG  Q_TG
# 0          1  127488  18760101  22     0
# 1          2  127488  18760102  25     0
# 2          3  127488  18760103   3     0
# 3          4  127488  18760104 -58     0
# 4          5  127488  18760105 -98     0
# ...      ...     ...       ...  ..   ...
# 52681  52682  111448  20200327  92     0
# 52682  52683  111448  20200328  79     0
# 52683  52684  111448  20200329  29     0
# 52684  52685  111448  20200330   6     0
# 52685  52686  111448  20200331  17     0
#
# [52491 rows x 5 columns]

# %%
data.plot.scatter('DATE', 'TG', s=0.001)
